# %% [markdown]
# # Jupyter Notebook
#
# De acordo com o site do projeto, o Jupyter Notebook é um aplicativo da Web de código aberto que permite criar e compartilhar documentos que contêm código ativo, equações, visualizações e texto narrativo.
#
# Este tipo de aplicativo é um recurso que permite estudo interativo, onde o leitor pode executar e modificar código e ver os resultados sem sair da pagina que está lendo.
#
# Sua linguagem padrão é o Python. Mas ele pode conectar-se a linguagens como o R, Julia, Ruby, Scala e Haskell. Atualmente, são suportadas mais de 40 linguagens de programação.
# <a href="https://ibb.co/Gsgc8Pn"><img src="https://i.ibb.co/n3hzYk6/Imagem0.png" alt="Imagem0" border="0"></a>

# %% [markdown]
# # Instalação e execução
#
# ## 1.	Começaremos   pesquisando  por Jupyter notebook.
#
# <a href="https://ibb.co/7vr9qMt"><img src="https://i.ibb.co/dBkhRC4/Imagem1.png" alt="Imagem1" border="0"></a>
#
# ## 2.	Clique no primeiro link:  jupyter.org
# <a href="https://ibb.co/DMS0SMV"><img src="https://i.ibb.co/JpMDMpB/Imagem2.png" alt="Imagem2" border="0"></a>
#
#
# ## 3.	Entrando no site você percebera que existe 2(duas) opções: a de testar em seu navegador, à esquerda . E a de instalar notebook , à direita.
# <a href="https://ibb.co/H7Sn7Bz"><img src="https://i.ibb.co/nrGzr6c/Imagem3.png" alt="Imagem3" border="0"></a>
#
# ## 4.	A maneira mais simples de instalar o Jupyter Notebook é instalar a distribuição Anaconda.
#
# <a href="https://ibb.co/8xmzbKT"><img src="https://i.ibb.co/QHJ8kbz/Imagem4.png" alt="Imagem4" border="0"></a>
#
# No site da distribuidora Anaconda encontraremos pacotes para Windows, Mac e Linux.
#
# <a href="https://ibb.co/cxfp2zb"><img src="https://i.ibb.co/hCQn2pX/Imagem5.png" alt="Imagem5" border="0"></a>
#
# Baixe a barra de seu navegador e você vera que já esta tarar direcionado o tipo de sistema de seu computador, meu caso Windows.
#
#  <a href="https://ibb.co/Lvbw6jy"><img src="https://i.ibb.co/9GzX2K0/Imagem6.png" alt="Imagem6" border="0"></a>
#
# Escolha a versão mais atual do python 3. Neste caso python 3.6.  Em seguida escolha entre 64-Bit ou 32-Bit, de acordo com sua máquina.
#
# <a href="https://ibb.co/XX0dgD3"><img src="https://i.ibb.co/5Tpzykn/Imagem7.png" alt="Imagem7" border="0"></a>
#
# Agora com download concluído é só clicar em Next para todas as opções.
#
# <a href="https://ibb.co/9ydCBGt"><img src="https://i.ibb.co/JrSM8CQ/Imagem8.png" alt="Imagem8" border="0"></a>
#
# ## 5.	Para rodar o Jupyter Notebook basta digitar na linha de comando: jupyter notebook
#
# <a href="https://ibb.co/M9MN9tT"><img src="https://i.ibb.co/sty3tNS/Imagem9.png" alt="Imagem9" border="0"></a>
#
# Ou ainda clique no ícone do Jupyter Notebook na pasta de instalação da Anaconda. Uma aba com a pasta padrão do Jupyter Notebook se abrirá no navegador padrão.
#
# ## Obs.:  Para parar o Jupyter Notebook deve-se fechar o terminal que abriu em paralelo. Fechar apenas a aba não termina o Jupyter Notebook.

# %% [markdown]
# # Atalhos de teclado, para o Jupyter Notebook
#
# Esc – Ativa o modo de comando, onde você pode navegar saltar as células de seu notebook com as teclas de seta.
#
# Enquanto  permanecer no modo de comando:
#
# A - Para inserir uma nova célula acima da célula atual;
#
# B - Para inserir uma nova célula abaixo;
#
# M - Para alterar a célula atual para Markdown;
#
# Y - Para alterá-lo de volta para o código;
#
# D + D (pressione a tecla duas vezes) - Para excluir a célula atual;
#
# Enter - O levará do modo de comando de volta ao modo de edição, onde você pode editar o texto nas células;
#
# Shift + Tab -  Mostrara o Docstring (documentação) para o objeto que você acabou de digitar em uma célula de código;
#
# Ctrl + Shift + - Dividi a célula atual em 2 (duas)  onde estiver o seu cursor;
#
# Esc + F - Encontre e substitua seu código, mas não as saídas;
#
# Esc + - O Alterna a saída da célula.
#
# Selecione várias células:
#
# Shift + J - Seleciona a próxima venda em uma direção para baixo;
#
# Shift + K - Seleciona vendas para cima;
#
# Depois que as células são selecionadas, você pode excluir / copiar / recortar / colar / executá-las como um lote.
#
# Shift + M- Mesclar várias células.

# %% [markdown]
# # Trabalhando no Jupyter Notebook
#
# 1.	Para criar um novo notebook, clicar em New (botão superior direito) e escolher qual a linguagem do novo notebook. Eu escolhi Python 3, como na figura abaixo.
#
# <a href="https://ibb.co/YLXyD46"><img src="https://i.ibb.co/QKkC87Z/Imagem10.png" alt="Imagem10" border="0"></a>
#
# 2.	Os Notebooks são divididos em células, células são pedaços de informações. Existem vários tipos de células: code, markdown e etc. Ao digitar em uma nova célula, você deve escolher se será uma célula contendo código ou marcações textuais (markdown).
#
# <a href="https://ibb.co/JHzGLfz"><img src="https://i.ibb.co/TtH7XVH/Imagem11.png" alt="Imagem11" border="0"></a>

# %% [markdown]
# # Markdown
#
# Os textos podem ser adicionados aos notebooks usando células Markdown. Markdown é uma linguagem de marcação popular que é um superconjunto de HTML.
#
# TÍTULOS
#
# Pra escrever títulos, podemos utilizar até 6 (seis)  # (cerquilhas):
# #Titulo 1;
# ##Subtítulo;
# ###SubSubtítulo ...
#
# Ou ,
#
# < h1>Titulo 1 </h1 >
#
# < h2>Subtítulo </h2 >
#
# < h3>SubSubtítulo </h3 >
#
# O resultado será o mesmo nos 2(dois) caso.
#
# ## Itálico, Negrito
#
# Podemos colocar palavras em itálico, negrito, sublinhar ou tachar, veja:

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.DataFrame({'Itálico' : ["*Italico*" ],
                   'Negrito' : ['**Negrito**'],
                   'Negrito/Italico' : ["***Itálico-Negrito**"],
                   'Tachado': ["~~Tachado~~"]
                   })
df
# Out:
#      Itálico      Negrito       Negrito/Italico      Tachado
# 0  *Italico*  **Negrito**  ***Itálico-Negrito**  ~~Tachado~~

# %% [markdown]
# ## Para justificar o texto:
#
# <a href="https://ibb.co/hMBTDmg"><img src="https://i.ibb.co/7zn021S/Imag2.png" alt="Imag2" border="0"></a>
#
# ## Tabela com o nome das cores:
#
# <a href="https://ibb.co/t4r5xM2"><img src="https://i.ibb.co/KXvHLjs/colors.png" alt="colors" border="0"></a>
#
# # Lista:
#
# Para criarmos uma lista não ordenada, temos que pular uma linha depois do ultimo paragrafo e colocarmos um * (asterisco) a frente do item listado.  Além do * (asterisco), podemos utilizar o sinal de + (soma) ou – (subtração) pra formarmos uma lista.
#
# veja:
#
# *Azul
# *Verde
# *Amarelo
# *Rosa
#
# Pra termos uma lista ordenada,
#
# 1.Azul
# 2.Verde
# 3.Amarelo
# 4.Rosa
#
# Para criamos uma lista aninhada, basta uma colocarmos o subitem com um espaço na frente:
#
# 1.Azul
#    1.Bola
#   2.Triangulo
#   3.Quadrado
# 2.Verde
# 3.Amarelo
#
# ## Links
#
#
# <a href="https://ibb.co/XCxfP37"><img src="https://i.ibb.co/FD4k105/Capturar1.png" alt="Capturar1" border="0"></a>
#
#
# ## imagens
#
# <a href="https://ibb.co/j5GRJWK"><img src="https://i.ibb.co/Dbkpr8X/Capturar2.png" alt="Capturar2" border="0"></a>
#
# ## Imagens links
#
# <a href="https://ibb.co/hs70s85"><img src="https://i.ibb.co/b1Wt1dh/Capturar4.png" alt="Capturar4" border="0"></a>
#
# ## Gifs
#
# <a href="https://ibb.co/3M9JqtX"><img src="https://i.ibb.co/z7TkYKc/Capturar5.png" alt="Capturar5" border="0"></a>

# %% [markdown]
# # LATEX
#
# Quando você escreve o LaTeX em uma célula Markdown, ele será renderizado como uma fórmula usando o MathJax. As fórmulas matemáticas podem ser escritas tanto no meio de um texto ou em destaque:
#
# 1.	No meio do texto deve-se usar o par de símbolos.
#
# <a href="https://ibb.co/PcFyjMd"><img src="https://i.ibb.co/sKb4RCZ/Imag.png" alt="Imag" border="0"></a>
#
# Exemplo:
#
# 2.	Em destaque, mostrada sozinha em uma única linha, deve-se usar em uma linha separada o par de símbolos.
#
# <a href="https://ibb.co/s9543VT"><img src="https://i.ibb.co/VYHGBqF/Imag1.png" alt="Imag1" border="0"></a>
#
# Exemplo:
#
# Construindo fórmulas:
#
# Sobrescrito – É feito usando: b^{x} onde b é a base e x o expoente.
#
# Sobescritos – É feito usando: b_{y} onde b é a base e y o índice.
#
# Raízes - São feitas usando: \sqrt[]{}.
#
# Frações - Podem ser feita usando:  /.
#
# Funções:
#
# •	\logx
# •	\sinx

# %% [markdown]
# # HTML
#
# Notebooks são exibidos como HTML e a saída da célula pode ser HTML, para que você possa retornar praticamente qualquer coisa: vídeo / simulações / imagens, adicionados aos notebooks usando células.
#
# ## Vídeo:
#
# Para inserir um vídeo no Jupyter Notebook, você deve digitar em uma célula code:  from IPython.display import HTML
#
# clicar: ENTER  e em seguida digitar:  HTML('Código de incorporação ')
#
# Exemplo:
#
# <a href="https://ibb.co/S5JZT39"><img src="https://i.ibb.co/ckxs5r7/Imagem12.png" alt="Imagem12" border="0"></a>
#
# ## Simulação:
#
# Para inserir uma simulação no Jupyter Notebook, você deve digitar em uma célula code: from IPython.display import HTML
#
# clicar: ENTER  e em seguida digitar: HTML('<iframe src="Código de incorporação" width="valor que desejar" height="valor que desejar" scrolling="no" allowfullscreen </iframe>')
#
# Exemplo:
#
# <a href="https://ibb.co/H71JDrs"><img src="https://i.ibb.co/7v89JG5/Imagem13.png" alt="Imagem13" border="0"></a>
#
# ## Imagem:
#
# Para inserir uma imagem no Jupyter Notebook, você deve digitar em uma célula code: from IPython.display import HTML
#
# clicar: ENTER  e em seguida digitar: HTML('<iframe src="Código de incorporação" width="valor que desejar" height="valor que desejar" scrolling="no" allowfullscreen </iframe>')
#
# Exemplo:
#
# <a href="https://ibb.co/QrbHZ0f"><img src="https://i.ibb.co/KF0sYnX/Imagem14.png" alt="Imagem14" border="0"></a>

# %% [markdown]
# # Gráficos e Tabelas:
#
# Para visualizar gráficos e tabelas em nossos Notebooks usaremos predominantemente as bibliotecas: Numpy, Panda e Matplotlib, Que funciona em perfeita harmonia nos documentos  com formato python 3. Elas podem ser visitadas facilmente clicando em help e logo em seguida um outro clique com o botão esquerdo do mouse sobre a que desejar visitar . Veja:
#
# <a href="https://ibb.co/rsHDBF4"><img src="https://i.ibb.co/ZmxqQGW/Imagem15.png" alt="Imagem15" border="0"></a>
#
# Numpy: O núcleo de extensões numéricas para álgebra linear e arrays multidimensionais;
#
# Pandas: É uma biblioteca de código aberto (BSD-licensed), fácil de usar na análise e estruturas de dados, para a lingugem python;
#
# Matplotlib: Excelente traçado e bibliotecas de gráficos.
#
# Tabelas:
#
# Para visualizar tabelas digite com as células em modo code:
#
# <a href="https://ibb.co/hBdZ1gt"><img src="https://i.ibb.co/Stmd769/Imagem17.png" alt="Imagem17" border="0"></a>
#
# Em seguida digite em uma nova célula:
#
# <a href="https://ibb.co/7CGyNxK"><img src="https://i.ibb.co/V9vBp0T/Imagem18.png" alt="Imagem18" border="0"></a>
#
# O resultado será:
#
# <a href="https://ibb.co/VSFbsdN"><img src="https://i.ibb.co/vPNfSbB/Imagem19.png" alt="Imagem19" border="0"></a>
#
# Gráficos:
#
# Para visualizar gráficos digite com as células em modo code:
#
# <a href="https://ibb.co/Rj31G81"><img src="https://i.ibb.co/J3vNWZN/Imagem20.png" alt="Imagem20" border="0"></a>
#
# Em seguida digite em uma nova célula:
#
# <a href="https://ibb.co/KFghNnD"><img src="https://i.ibb.co/WgX5DC0/Imagem21.png" alt="Imagem21" border="0"></a>
#
# em uma nova célula:
#
# <a href="https://ibb.co/1KLPJ02"><img src="https://i.ibb.co/820f4m8/Imagem22.png" alt="Imagem22" border="0"></a>
#
# O resultado será:
#
# <a href="https://ibb.co/DtydbKh"><img src="https://i.ibb.co/s2G7P3n/Imagem23.png" alt="Imagem23" border="0"></a>
#
# # Widgets:
#
# Use widgets para criar GUIs interativas para seus notebooks.
#
# <a href="https://ibb.co/WgNTwVX"><img src="https://i.ibb.co/qkLZfJ8/Imagem26.png" alt="Imagem26" border="0"></a>
#
# Usando widgets:
#
# <a href="https://ibb.co/KNz6f8t"><img src="https://i.ibb.co/s5JjNXT/Imagem24.png" alt="Imagem24" border="0"></a>
#
# <a href="https://ibb.co/nBCYHHW"><img src="https://i.ibb.co/ZSmFnnZ/Imagem25.png" alt="Imagem25" border="0"></a>
#
# # Salvando os notebook:
#
# Os documentos Jupyter Notebooks podem ser convertidos em outros formatos como HTML, slides, Latex, PDF, Python, etc. Estas conversões podem ocorrer através da interface Web (via “Download As”) ou via o comando em linha de programa jupyter nbconvert.
#
# <a href="https://ibb.co/VNKwhxR"><img src="https://i.ibb.co/PYSDbMK/Imagem27.png" alt="Imagem27" border="0"></a>
